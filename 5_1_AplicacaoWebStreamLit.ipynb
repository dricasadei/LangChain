# %% [markdown]
# ![image.png](attachment:5e183e5d-569a-4515-adb9-fa0850febced.png)

# %%
# !streamlit run 5_2_AplicacaoStreamlit.py

# %%
# !streamlit run 5_2_AplicacaoStreamlitSidebar.py 
# Modificações realizadas:
    # pedindo para o modelo formatar o relatório conforme markdown - nova instrução no template do prompt
    # organizando a página deixando os sidebars na esquerda e a página livre para a geração do relatório gerado.
